# %% [markdown]
# ![logo](1_bDwEvCRgrKVbLrAXEixpfA.png)
# ___

# %% [markdown]
# ##### import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Step 1 - Import and set up data

# %%
#import .csv file
raw_kickstarter_df = pd.read_csv("kickstarter_all.csv")

#check datatypes
print(raw_kickstarter_df.dtypes)
raw_kickstarter_df.head()
# Out:
# C:\Users\vlad_\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (3,6,12,15,16,17,21,26,33,34,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# backers_count               object
# blurb                       object
# category                    object
# converted_pledged_amount    object
# country                     object
# country_displayable_name    object
# created_at                  object
# creator                     object
# currency                    object
# currency_symbol             object
# currency_trailing_code      object
# current_currency            object
# deadline                    object
# disable_communication       object
# friends                     object
# fx_rate                     object
# goal                        object
# id                          object
# is_backing                  object
# ...

# %%
raw_kickstarter_df.shape
# Out:
# (215858, 38)

# %%
#dropping columns
raw_kickstarter_df.drop(['country_displayable_name',
                         'creator',
                         'currency_symbol',
                         'currency_trailing_code',
                         'current_currency',
                         'friends',
                         'is_backing',
                         'is_starred',
                         'location',
                         'permissions',
                         'photo',
                         'profile',
                         'urls',
                         'pledged',
                         'static_usd_rate',
                         'usd_pledged',
                         'fx_rate',
                         'usd_type'], axis=1, inplace=True)

# %% [markdown]
# ### End of Step 1

# %%
#write a more practical .csv for Step 2
raw_kickstarter_df.to_csv('kickstarter_data.csv')
